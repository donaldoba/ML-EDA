# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import seaborn as sns

# %%
data=pd.read_csv("GenZ_DatingApp_Data.csv")

# %%
data.head
# Out:
# <bound method NDFrame.head of      User_ID  Age      Gender   Location      Education     Occupation  \
# 0          1   20  Non-binary  Bangalore  Undergraduate     Freelancer
# 1          2   24      Female      Delhi  Undergraduate  Part-time Job
# 2          3   24  Non-binary    Kolkata  Undergraduate         Intern
# 3          4   22  Non-binary      Delhi       Graduate  Full-time Job
# 4          5   18        Male      Delhi       Graduate         Intern
# ..       ...  ...         ...        ...            ...            ...
# 495      496   23      Female     Mumbai  Undergraduate         Intern
# 496      497   23        Male     Mumbai   Postgraduate         Intern
# 497      498   22        Male  Hyderabad       Graduate     Freelancer
# 498      499   21      Female    Kolkata       Graduate        Student
# 499      500   22        Male     Mumbai       Graduate  Part-time Job
#
#     Primary_App Secondary_Apps Usage_Frequency Daily_Usage_Time  \
# ...

# %%
data.head()
# Out:
#    User_ID  Age      Gender   Location      Education     Occupation  \
# 0        1   20  Non-binary  Bangalore  Undergraduate     Freelancer
# 1        2   24      Female      Delhi  Undergraduate  Part-time Job
# 2        3   24  Non-binary    Kolkata  Undergraduate         Intern
# 3        4   22  Non-binary      Delhi       Graduate  Full-time Job
# 4        5   18        Male      Delhi       Graduate         Intern
#
#   Primary_App Secondary_Apps Usage_Frequency Daily_Usage_Time  \
# 0       Hinge          Hinge         Monthly           1 hour
# 1       Hinge        OkCupid          Weekly       30 minutes
# 2     OkCupid          Hinge          Weekly          2 hours
# 3     OkCupid        OkCupid           Daily       30 minutes
# 4     OkCupid        OkCupid          Weekly          2 hours
#
#     Reason_for_Using  Satisfaction               Challenges  \
# 0  Finding a Partner             4          Safety Concerns
# ...

# %%
#- if i were a new data scientist joining a project , i would need to  : 
#. understand the data structure (columns,data types ,missing values, outliers)
#. know the business context 
#. Track changes over time 
data.shape
data.describe()
# Out:
#           User_ID         Age  Satisfaction
# count  500.000000  500.000000    500.000000
# mean   250.500000   21.582000      2.906000
# std    144.481833    2.259532      1.441291
# min      1.000000   18.000000      1.000000
# 25%    125.750000   20.000000      2.000000
# 50%    250.500000   22.000000      3.000000
# 75%    375.250000   24.000000      4.000000
# max    500.000000   25.000000      5.000000

# %%
# A good column description should be:
#Clear & concise, Explain the purpose,Include data types & units,Mention possible values and Describe missing values
data_dictionary = pd.DataFrame({
    'Column Name': data.columns,
    'Data Type': data.dtypes.values,
    'Missing Values': data.isnull().sum().values,
    'Unique Values': [data[col].nunique() for col in data.columns],
    'Sample Values': [data[col].unique()[:5] for col in data.columns]  
})

display(data_dictionary)
# Out:
#                 Column Name Data Type  Missing Values  Unique Values  \
# 0                   User_ID     int64               0            500
# 1                       Age     int64               0              8
# 2                    Gender  category               0              3
# 3                  Location  category               0              7
# 4                 Education  category               0              3
# 5                Occupation  category               0              5
# 6               Primary_App  category               0              4
# 7            Secondary_Apps  category               0              4
# 8           Usage_Frequency  category               0              3
# 9          Daily_Usage_Time  category               0              5
# 10         Reason_for_Using  category               0              4
# 11             Satisfaction     int64               0              5
# 12               Challenges  category               0              3
# ...

# %%
# To track changes in a dataset over time the best way will be 
#Use Version Control (DVC/Git) to track versions and changes efficiently.
#Use Delta Tables for large datasets in distributed systems.
#Add timestamps for every update to keep a history of when data changes.
#Maintain a change log (manual or automated) to capture the reasoning behind updates.
#Compare dataset versions to identify specific differences between versions
